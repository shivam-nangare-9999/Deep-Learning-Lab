# %%
Name Shivam Nangare
Roll no ACT 45

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
from tensorflow.keras.optimizers import SGD
import matplotlib.pyplot as plt

# %%
# load traning and testing data
(x_train,y_train),(x_test, y_test) = mnist.load_data()

# %%
#normalize the data
x_train = x_train /255.0
x_test = x_test / 255.0

# %%
# define the netork architecture
model = Sequential()

# input layer + flatten
model.add(Flatten(input_shape=(28,28)))

#hidden layer
model.add(Dense(128,activation='relu'))

#output layer

model.add(Dense(10, activation='softmax'))

# %%
#compile the model using SGD optimizer
model.compile(optimizer=SGD(learning_rate=0.01), loss ='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# train the model
history = model.fit(x_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_data=(x_test , y_test) )
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7247 - loss: 1.0363 - val_accuracy: 0.9025 - val_loss: 0.3569
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9019 - loss: 0.3523 - val_accuracy: 0.9183 - val_loss: 0.2927
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9176 - loss: 0.2975 - val_accuracy: 0.9286 - val_loss: 0.2614
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9274 - loss: 0.2627 - val_accuracy: 0.9346 - val_loss: 0.2357
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9353 - loss: 0.2349 - val_accuracy: 0.9377 - val_loss: 0.2195
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9413 - loss: 0.2129 - val_accuracy: 0.9427 - val_loss: 0.2035
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9452 - loss: 0.2018 - val_accuracy: 0.9471 - val_loss: 0.1890
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9498 - loss: 0.1809 - val_accuracy: 0.9494 - val_loss: 0.1778
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9517 - loss: 0.1726 - val_accuracy: 0.9526 - val_loss: 0.1692
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9557 - loss: 0.1609 - val_accuracy: 0.9539 - val_loss: 0.1616

# %%
# evaluate the network
test_loss, test_accuracy = model.evaluate(x_test,y_test)
print("test loss",test_loss)
print("test accuracy",test_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9447 - loss: 0.1886
# test loss 0.1616383045911789
# test accuracy 0.9538999795913696

# %%
# plot traning loss and accuracy
# plot loss
plt.plot(history.history['loss'],label='traning loss')
plt.plot(history.history['val_loss'],label='validation loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

#plot accuracy
# plot traning loss and accuracy
# plot loss
plt.plot(history.history['accuracy'],label='traning accuracy')
plt.plot(history.history['val_accuracy'],label='validation accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()
